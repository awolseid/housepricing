# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
housing = pd.read_csv("housing.csv")
housing
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.199997  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.900002  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.099998  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.799999  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.200001  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.099998  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.699997  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.300003  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.800003  2.5050    1  273
#
#             PT           B  LSTAT      Price
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class LikeBuiltinData:
    def __init__(self, dataframe: pd.DataFrame = housing):
        self.dataframe = dataframe
        
    @property
    def data(self):
        return housing.iloc[: , :-1].to_numpy()
    
    @property
    def target(self):
        return housing["Price"].to_numpy()
    
    @property
    def feature_names(self):
        return housing.iloc[: , :-1].columns.tolist()
    
    @property
    def DESCR(self):
        return "This is the Boston Housing dataset."

    
price_dataset = LikeBuiltinData()
price_dataset.feature_names
# Out:
# ['CRIM',
#  'ZN',
#  'INDUS',
#  'CHAS',
#  'NOX',
#  'RM',
#  'AGE',
#  'DIS',
#  'RAD',
#  'TAX',
#  'PT',
#  'B',
#  'LSTAT']

# %%
print(price_dataset.data)
# Out:
# [[6.32000000e-03 1.80000000e+01 2.30999994e+00 ... 1.53000002e+01
#   3.96899994e+02 4.98000002e+00]
#  [2.73100010e-02 0.00000000e+00 7.07000017e+00 ... 1.77999992e+01
#   3.96899994e+02 9.14000034e+00]
#  [2.72900000e-02 0.00000000e+00 7.07000017e+00 ... 1.77999992e+01
#   3.92829987e+02 4.03000021e+00]
#  ...
#  [6.07599990e-02 0.00000000e+00 1.19300003e+01 ... 2.10000000e+01
#   3.96899994e+02 5.63999987e+00]
#  [1.09590001e-01 0.00000000e+00 1.19300003e+01 ... 2.10000000e+01
#   3.93450012e+02 6.48000002e+00]
#  [4.74100000e-02 0.00000000e+00 1.19300003e+01 ... 2.10000000e+01
#   3.96899994e+02 7.88000011e+00]]

# %%
# print(price_dataset.target)

# %% [markdown]
# ## Prepare Dataset

# %%
dataset = pd.DataFrame(price_dataset.data, columns = price_dataset.feature_names)
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.199997  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900002  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.099998  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.799999  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200001  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.099998  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.699997  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300003  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.800003  2.5050  1.0  273.0
#
#             PT           B  LSTAT
# ...

# %%
dataset["Price"] = price_dataset.target
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.199997  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900002  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.099998  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.799999  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200001  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.099998  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.699997  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300003  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.800003  2.5050  1.0  273.0
#
#             PT           B  LSTAT      Price
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CRIM    506 non-null    float64
#  1   ZN      506 non-null    float64
#  2   INDUS   506 non-null    float64
#  3   CHAS    506 non-null    float64
#  4   NOX     506 non-null    float64
#  5   RM      506 non-null    float64
#  6   AGE     506 non-null    float64
#  7   DIS     506 non-null    float64
#  8   RAD     506 non-null    float64
#  9   TAX     506 non-null    float64
#  10  PT      506 non-null    float64
#  11  B       506 non-null    float64
#  12  LSTAT   506 non-null    float64
#  13  Price   506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
### Summarizing the stats of data
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976196  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX          PT           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674030
# ...

# %%
### Check for missing values
dataset.isnull()
# Out:
#       CRIM     ZN  INDUS   CHAS    NOX     RM    AGE    DIS    RAD    TAX  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 501  False  False  False  False  False  False  False  False  False  False
# 502  False  False  False  False  False  False  False  False  False  False
# 503  False  False  False  False  False  False  False  False  False  False
# 504  False  False  False  False  False  False  False  False  False  False
# 505  False  False  False  False  False  False  False  False  False  False
#
#         PT      B  LSTAT  Price
# 0    False  False  False  False
# ...

# %%
dataset.isnull().sum()
# Out:
# CRIM     0
# ZN       0
# INDUS    0
# CHAS     0
# NOX      0
# RM       0
# AGE      0
# DIS      0
# RAD      0
# TAX      0
# PT       0
# B        0
# LSTAT    0
# Price    0
# dtype: int64

# %%
### Exploratory data analysis
#### Correlation

dataset.corr()
# Out:
#            CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM   1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN    -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS  0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS  -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX    0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM    -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE    0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS   -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD    0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX    0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PT     0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355502  0.261515
# ...

# %%
import seaborn as sns

# %%
# sns.pairplot(dataset)

# %%
plt.scatter(dataset["CRIM"], dataset["Price"])
plt.ylabel("Price")
plt.xlabel("Crime rate");

# %%
plt.scatter(dataset["RM"], dataset["Price"])
plt.ylabel("Price")
plt.xlabel("Number of rooms");

# %%
import seaborn as sns
sns.regplot(x = "RM", y = "Price", data = dataset);

# %%
sns.regplot(x = "LSTAT", y = "Price", data = dataset);

# %%
sns.regplot(x = "CHAS", y = "Price", data = dataset);

# %%
sns.regplot(x = "PT", y = "Price", data = dataset);

# %%
### Independent and Dependent Features

X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.199997  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900002  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.099998  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.799999  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200001  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.099998  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.699997  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300003  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.800003  2.5050  1.0  273.0
#
#             PT           B  LSTAT
# ...

# %%
y
# Out:
# 0      24.000000
# 1      21.600000
# 2      34.700001
# 3      33.400002
# 4      36.200001
#          ...
# 501    22.400000
# 502    20.600000
# 503    23.900000
# 504    22.000000
# 505    11.900000
# Name: Price, Length: 506, dtype: float64

# %%
### Train Test Split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS   RAD  \
# 5     0.02985   0.0   2.18   0.0  0.458  6.430  58.700001  6.0622   3.0
# 116   0.13158   0.0  10.01   0.0  0.547  6.176  72.500000  2.7301   6.0
# 45    0.17142   0.0   6.91   0.0  0.448  5.682  33.799999  5.1004   3.0
# 16    1.05393   0.0   8.14   0.0  0.538  5.935  29.299999  4.4986   4.0
# 468  15.57570   0.0  18.10   0.0  0.580  5.926  71.000000  2.9084  24.0
# ..        ...   ...    ...   ...    ...    ...        ...     ...   ...
# 106   0.17120   0.0   8.56   0.0  0.520  5.836  91.900002  2.2110   5.0
# 270   0.29916  20.0   6.96   0.0  0.464  5.856  42.099998  4.4290   3.0
# 348   0.01501  80.0   2.01   0.0  0.435  6.635  29.700001  8.3440   4.0
# 435  11.16040   0.0  18.10   0.0  0.740  6.629  94.599998  2.1247  24.0
# 102   0.22876   0.0   8.56   0.0  0.520  6.405  85.400002  2.7147   5.0
#
#        TAX         PT           B      LSTAT
# 5    222.0  18.700001  394.119995   5.210000
# ...

# %%
X_test
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM         AGE     DIS   RAD  \
# 173  0.09178   0.0   4.05   0.0  0.510  6.416   84.099998  2.6463   5.0
# 274  0.05644  40.0   6.41   1.0  0.447  6.758   32.900002  4.0776   4.0
# 491  0.10574   0.0  27.74   0.0  0.609  5.983   98.800003  1.8681   4.0
# 72   0.09164   0.0  10.81   0.0  0.413  6.065    7.800000  5.2873   4.0
# 452  5.09017   0.0  18.10   0.0  0.713  6.297   91.800003  2.3682  24.0
# ..       ...   ...    ...   ...    ...    ...         ...     ...   ...
# 441  9.72418   0.0  18.10   0.0  0.740  6.406   97.199997  2.0651  24.0
# 23   0.98843   0.0   8.14   0.0  0.538  5.813  100.000000  4.0952   4.0
# 225  0.52693   0.0   6.20   0.0  0.504  8.725   83.000000  2.8944   8.0
# 433  5.58107   0.0  18.10   0.0  0.713  6.436   87.900002  2.3158  24.0
# 447  9.92485   0.0  18.10   0.0  0.740  6.251   96.599998  2.1980  24.0
#
#        TAX         PT           B      LSTAT
# 173  296.0  16.600000  395.500000   9.040000
# ...

# %%
### Standardize dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
import pickle

pickle.dump(scaler, open("scaling.pkl", "wb"))

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test) # in the test dataset, no fit_transform

# %%
X_train
# Out:
# array([[-0.41425879, -0.50512499, -1.29214217, ...,  0.18727102,
#          0.39651416, -1.0153161 ],
#        [-0.40200818, -0.50512499, -0.16208343, ..., -0.21209022,
#          0.38706728, -0.05366252],
#        [-0.39721054, -0.50512499, -0.6094886 , ..., -0.16771666,
#          0.42854109, -0.31132372],
#        ...,
#        [-0.41604586,  3.03838247, -1.3166773 , ..., -0.56707705,
#          0.35987911, -0.90549333],
#        [ 0.926113  , -0.50512499,  1.00549961, ...,  0.85287195,
#         -2.87841349,  1.52750443],
#        [-0.3903055 , -0.50512499, -0.37135353, ...,  1.16348521,
#         -3.3282883 , -0.25218835]])

# %%
X_test
# Out:
# array([[-0.40680101, -0.50512499, -1.02225584, ..., -0.74457046,
#          0.41241248, -0.47605795],
#        [-0.41105675,  1.26662874, -0.68165071, ..., -0.30083651,
#          0.42854109, -1.25185755],
#        [-0.40511991, -0.50512499,  2.3967851 , ...,  0.80849839,
#          0.35031691,  0.79535225],
#        ...,
#        [-0.35439904, -0.50512499, -0.7119588 , ..., -0.38958363,
#          0.25688596, -1.0969792 ],
#        [ 0.25423453, -0.50512499,  1.00549961, ...,  0.85287195,
#         -2.98970131,  0.53487502],
#        [ 0.77732465, -0.50512499,  1.00549961, ...,  0.85287195,
#          0.33199939,  0.56585085]])

# %% [markdown]
# ## Model Training

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()
regression
# Out:
# LinearRegression()

# %%
regression.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regression.get_params()
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
### print coefficients and intercept
print(regression.coef_)
# Out:
# [-1.10834606  0.80843998  0.34313504  0.81386425 -1.79804334  2.91385779
#  -0.29893915 -2.94251136  2.09419346 -1.44706731 -2.05232256  1.02375187
#  -3.88579018]

# %%
print(regression.intercept_)
# Out:
# 23.0158192288983

# %%
# prediction with Test Data
reg_pred = regression.predict(X_test)
reg_pred
# Out:
# array([28.64895916, 36.49501322, 15.41119213, 25.40321346, 18.85527915,
#        23.14668859, 17.39212432, 14.07859719, 23.0369279 , 20.59943284,
#        24.8228625 , 18.53057127, -6.86543563, 21.80172245, 19.22571286,
#        26.19191966, 20.27734033,  5.61596472, 40.44888032, 17.57695927,
#        27.44319008, 30.17159598, 10.94055784, 24.02083048, 18.07693849,
#        15.93474908, 23.1261401 , 14.56052242, 22.33482536, 19.3257627 ,
#        22.16564963, 25.19476114, 25.31372524, 18.51345102, 16.62232872,
#        17.50268528, 30.94992974, 20.19201676, 23.90440487, 24.86975443,
#        13.93767808, 31.82504713, 42.56978939, 17.62323799, 27.01963199,
#        17.19006543, 13.80594079, 26.10356508, 20.31516055, 30.08649429,
#        21.31240509, 34.15739626, 15.60445085, 26.1124767 , 39.31613505,
#        22.99282047, 18.95764683, 33.05555606, 24.85114219, 12.91729492,
#        22.68101458, 30.8033639 , 31.63522097, 16.29833681, 21.07380042,
# ...

# %%
### plot scatter plot for the prediction
plt.scatter(reg_pred, y_test);

# %%
residuals = y_test - reg_pred
residuals
# Out:
# 173    -5.048959
# 274    -4.095012
# 491    -1.811192
# 72     -2.603214
# 452    -2.755279
#          ...
# 441    -0.303671
# 23      1.114057
# 225    10.016574
# 433    -2.382863
# 447    -5.685616
# Name: Price, Length: 152, dtype: float64

# %%
### plot of residuals
sns.displot(residuals, kind = "kde");

# %%
### scatter plot of predictions and residuals
plt.scatter(reg_pred, residuals)

# %%
### Performance metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
print(mean_squared_error(y_test, reg_pred))
print(mean_absolute_error(y_test, reg_pred))
print(np.sqrt(mean_squared_error(y_test, reg_pred)))
# Out:
# 21.517442983048866
# 3.162709796484625
# 4.638689791638245

# %%
### R Square and adjusted R Square
from sklearn.metrics import r2_score
r2_score = r2_score(y_test, reg_pred)
print(r2_score)
# Out:
# 0.7112260293950656

# %%
adj_r2 = 1 - (1 - r2_score) * (len(y_test) - 1) / (len(y_test) - X_test.shape[1] - 1)
print(adj_r2)
# Out:
# 0.684022684338079

# %% [markdown]
# ## New data prediction

# %% [markdown]
# ##### Single data point input shape

# %%
price_dataset.data
# Out:
# array([[6.32000000e-03, 1.80000000e+01, 2.30999994e+00, ...,
#         1.53000002e+01, 3.96899994e+02, 4.98000002e+00],
#        [2.73100010e-02, 0.00000000e+00, 7.07000017e+00, ...,
#         1.77999992e+01, 3.96899994e+02, 9.14000034e+00],
#        [2.72900000e-02, 0.00000000e+00, 7.07000017e+00, ...,
#         1.77999992e+01, 3.92829987e+02, 4.03000021e+00],
#        ...,
#        [6.07599990e-02, 0.00000000e+00, 1.19300003e+01, ...,
#         2.10000000e+01, 3.96899994e+02, 5.63999987e+00],
#        [1.09590001e-01, 0.00000000e+00, 1.19300003e+01, ...,
#         2.10000000e+01, 3.93450012e+02, 6.48000002e+00],
#        [4.74100000e-02, 0.00000000e+00, 1.19300003e+01, ...,
#         2.10000000e+01, 3.96899994e+02, 7.88000011e+00]])

# %%
price_dataset.data[0]
# Out:
# array([6.32000000e-03, 1.80000000e+01, 2.30999994e+00, 0.00000000e+00,
#        5.37999988e-01, 6.57499981e+00, 6.51999969e+01, 4.09000015e+00,
#        1.00000000e+00, 2.96000000e+02, 1.53000002e+01, 3.96899994e+02,
#        4.98000002e+00])

# %%
price_dataset.data[0].shape
# Out:
# (13,)

# %%
price_dataset.data[0].reshape(1, -1) # this is the required shape for prediction
# Out:
# array([[6.32000000e-03, 1.80000000e+01, 2.30999994e+00, 0.00000000e+00,
#         5.37999988e-01, 6.57499981e+00, 6.51999969e+01, 4.09000015e+00,
#         1.00000000e+00, 2.96000000e+02, 1.53000002e+01, 3.96899994e+02,
#         4.98000002e+00]])

# %%
price_dataset.data[0].reshape(1, -1).shape
# Out:
# (1, 13)

# %%
print(regression.predict(price_dataset.data[0].reshape(1, -1)))
## note that the model is estimated using standardized values
# Out:
# [-45.64345052]

# %%
scaled_input = scaler.transform(price_dataset.data[0].reshape(1, -1))
print(scaled_input)
# Out:
# [[-0.41709234  0.29216419 -1.27338004 -0.28154625 -0.16513641  0.34715875
#   -0.1303007   0.1526717  -0.97798895 -0.66777595 -1.32142469  0.42854109
#   -1.04769975]]
# c:\Users\Administrator\Desktop\ML_Deployment\housepricing\venv\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
print(regression.predict(scaled_input)) 
## Still there are some differences with the reg_pred values above. Why? I do have to figure it out.
# Out:
# [30.08649429]

# %% [markdown]
# ## Pick the mode file for deployment

# %%
import pickle

# %%
pickle.dump(obj = regression, file = open("regmodel.pkl", "wb")) # write bite mode

# %%
# prediction
pickled_model = pickle.load(open("regmodel.pkl", "rb")) # read bite mode

# %%
print(pickled_model.predict(scaled_input))
# Out:
# [30.08649429]
